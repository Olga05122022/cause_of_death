# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as py
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv('cause_of_deaths.csv')

# %%
df = df.rename(columns={'Country/Territory':'country', 'Year':'year'})

# %%
df.country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 6115       Zimbabwe
# 6116       Zimbabwe
# 6117       Zimbabwe
# 6118       Zimbabwe
# 6119       Zimbabwe
# Name: country, Length: 6120, dtype: object

# %%
rus_df = df.loc[df.country == 'Russia']

# %%
rus_df.columns
# Out:
# Index(['country', 'Code', 'year', 'Meningitis',
#        'Alzheimer's Disease and Other Dementias', 'Parkinson's Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis'],
#       dtype='object')

# %%
rus_total_death = rus_df.sum()

# %%
string_list = ['Meningitis',
       "Alzheimer's Disease and Other Dementias", "Parkinson's Disease",
       'Nutritional Deficiencies', 'Malaria', 'Drowning',
       'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
       'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
       'Lower Respiratory Infections', 'Neonatal Disorders',
       'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
       'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
       'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
       'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
       'Road Injuries', 'Chronic Respiratory Diseases',
       'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
       'Fire, Heat, and Hot Substances', 'Acute Hepatitis']

integer_list = [60135, 60519, 972305, 236367, 15906, 0, 423044, 1215179, 15028, 350679, 259452, 529853, 33903781, 1113475, 237923, 1194672, 
1793855, 3086, 27964, 573771, 9079313, 39125, 369649, 325433, 298954, 8167, 1067225, 1518195, 1233608, 2398456, 322573, 3598]

rus_total_death = pd.DataFrame(list(zip( string_list, integer_list)), columns = ['cause', 'number'])

# %%
plt.figure(figsize=(15,8),dpi=200)
sns.barplot(data=rus_total_death, x='number', y='cause')
plt.xlabel('number')
plt.ylabel('cause')
plt.title("Number of death in Russia from different causes")
plt.show()

# %%
rus_total_death['proportion'] = round(rus_total_death.number / rus_total_death.number.sum() *100)

# %%
rus_total_death_top_5 = rus_total_death.sort_values(by=['proportion'],ascending=False).head(115)

# %%
rus_total_death_top_5
# Out:
#                                          cause    number  proportion
# 12                Lower Respiratory Infections  33903781        57.0
# 20                      Conflict and Terrorism   9079313        15.0
# 29              Fire, Heat, and Hot Substances   2398456         4.0
# 16                Exposure to Forces of Nature   1793855         3.0
# 27  Cirrhosis and Other Chronic Liver Diseases   1518195         3.0
# 15                                   Self-harm   1194672         2.0
# 2                          Parkinson's Disease    972305         2.0
# 28                          Digestive Diseases   1233608         2.0
# 26                Chronic Respiratory Diseases   1067225         2.0
# 7                           Maternal Disorders   1215179         2.0
# 13                          Neonatal Disorders   1113475         2.0
# 24                 Protein-Energy Malnutrition    298954         1.0
# 23                                  Poisonings    325433         1.0
# ...

# %%
cause_of_deaths = ['Meningitis',
       "Alzheimer's Disease and Other Dementias", "Parkinson's Disease",
       'Nutritional Deficiencies', 'Malaria', 'Drowning',
       'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
       'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
       'Lower Respiratory Infections', 'Neonatal Disorders',
       'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
       'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
       'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
       'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
       'Road Injuries', 'Chronic Respiratory Diseases',
       'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
       'Fire, Heat, and Hot Substances', 'Acute Hepatitis']

# %%
rus_df['total_number_of_deaths'] = rus_df[cause_of_deaths].sum(axis=1)
# Out:
# C:\Users\Оля\AppData\Local\Temp\ipykernel_10648\546092641.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(15,8),dpi=200)
sns.barplot(data=rus_df, x='year', y='total_number_of_deaths', color='0.5')
plt.xlabel("year")
plt.ylabel("total number of deaths")
plt.title("Total number of deaths in Russia")
plt.show();

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='Lower Respiratory Infections', color='0.3')
plt.xlabel('year')
plt.ylabel('Lower Respiratory Infections')
plt.title("Death from Lower Respiratory Infections in Russia")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='Conflict and Terrorism',color='0.4')
plt.xlabel('year')
plt.ylabel('Conflict and Terrorism')
plt.title("Death from Conflict and Terrorism in Russia")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='Fire, Heat, and Hot Substances', color='0.5')
plt.xlabel('year')
plt.ylabel('Fire, Heat, and Hot Substances')
plt.title("Death from Fire, Heat, and Hot Substances in Russia")

plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='Exposure to Forces of Nature', color='0.7')
plt.xlabel('year')
plt.ylabel('Exposure to Forces of Nature')
plt.title("Death from Exposure to Forces of Nature in Russia")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='Cirrhosis and Other Chronic Liver Diseases', color='0.7')
plt.xlabel('year')
plt.ylabel('Cirrhosis and Other Chronic Liver Diseases')
plt.title("Death from Cirrhosis and Other Chronic Liver Diseases in Russia")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='Self-harm', color='0.3')
plt.xlabel('year')
plt.ylabel('Self-harm')
plt.title("Death from Self-harm in Russia")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y="Parkinson's Disease", color='0.3')
plt.xlabel('year')
plt.ylabel("Parkinson's Disease")
plt.title("Death from Parkinson's Disease in Russia")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='Digestive Diseases', color='0.3')
plt.xlabel('year')
plt.ylabel('Digestive Diseases')
plt.title("Death from Digestive Diseases in Russia")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='Chronic Respiratory Diseases', color='0.3')
plt.xlabel('year')
plt.ylabel('Chronic Respiratory Diseases')
plt.title("Death from Chronic Respiratory Diseases in Russia")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='Maternal Disorders', color='0.3')
plt.xlabel('year')
plt.ylabel('Maternal Disorders')
plt.title("Death from Maternal Disorders in Russia")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='Neonatal Disorders', color='0.3')
plt.xlabel('year')
plt.ylabel('Neonatal Disorders')
plt.title("Death from Neonatal Disorders in Russia")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='Cardiovascular Diseases', color='0.3')
plt.xlabel('year')
plt.ylabel('Cardiovascular Diseases')
plt.title("Death from Cardiovascular Diseases in Russia")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='Drug Use Disorders', color='0.3')
plt.xlabel('year')
plt.ylabel('Drug Use Disorders')
plt.title("Death from Drug Use Disorders in Russia")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(data=rus_df, x='year', y='HIV/AIDS', color='0.3')
plt.xlabel('year')
plt.ylabel('HIV/AIDS')
plt.title("Death from HIV/AIDS in Russia")
plt.show()
